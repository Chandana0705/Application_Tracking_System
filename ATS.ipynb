# %%
pip install PyPDF2

# %%
import PyPDF2
def extract_text_from_pdf(pdf_path):
    """
    Extracts text from all pages of a PDF file.
    """
    extracted_text = ""

    with open(pdf_path, "rb") as file:
        reader = PyPDF2.PdfReader(file)

        for page in reader.pages:
            page_text = page.extract_text()
            if page_text:
                extracted_text += page_text

    return extracted_text
print(extract_text_from_pdf("Chandana's_resume.pdf"))
# Out:
# KURAPATI CHANDANA SAI SREE
# kurapatichandana64@gmail.com — +91-7995023605 — LinkedIn — GitHub
# Executive Summary
# Aspiring Software Engineer with a strong foundation in Java and Python, complemented by knowledge of
# machine learning fundamentals. Proficient in working with MySQL databases, including schema design and
# query optimization. Experienced in building Agentic AI and Generative AI applications with a solid
# understanding of prompt engineering. Passionate about developing scalable, secure software solutions and
# integrating AI capabilities into real-world applications.
# Education
# Vishnu Institute of Technology, Bhimavaram2023 – Present
# B.Tech in Information Technology
# CGPA: 9.51
# Experience
# AIML Intern — AICTE Internship Program2025
# •Worked on applying core concepts of Artificial Intelligence and Machine Learning to real-world problem
# statements.
# •Built and evaluated basic ML models for classification and prediction tasks using Python.
# ...

# %%
text=extract_text_from_pdf("Chandana's_resume.pdf")

# %%
from google import genai
client = genai.Client(api_key='')

response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents=f"Here is the context:{text} your ques:give me the rating that is the ATS scre of my resume and tellme where imporvements are required"

)
print(response.text)
# Out:
# Okay, let's break down your resume for an ATS (Applicant Tracking System) screen.
#
# **ATS Score: Approximately 75-80%** (With a critical flaw that needs immediate attention)
#
# **Here's a detailed breakdown of strengths and areas for improvement:**
#
# ---
#
# ### ATS Strengths (Why it scores well):
#
# 1.  **Excellent Keyword Density:** Your "Executive Summary" and "Skills" sections are packed with relevant keywords (Java, Python, Machine Learning, Generative AI, Prompt Engineering, MySQL, Git, GitHub, OOPS, Data Structures). This is crucial for ATS.
# 2.  **Clear & Standard Section Headers:** "Executive Summary," "Education," "Experience," "Projects," "Skills," "Certifications," "Achievements" are all standard and easily parseable by an ATS.
# 3.  **Clean Formatting:** The use of bullet points, clear headings, and a standard font makes it easy for an ATS to read and extract information. No complex graphics or images.
# ...

# %%
def parse_resume(resume_text):
    prompt = f"""
You are a resume parser.

Extract:
- Skills
- Experience summary
- Education
- Tools & technologies

Resume:
{resume_text}

Return in bullet points.
"""
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=prompt
    )
    return response.text
print(parse_resume(text))
# Out:
# Here's the extracted information from the resume:
#
# **Skills**
# *   Java
# *   Python
# *   C
# *   Generative AI
# *   Agentic AI
# *   Prompt Engineering
# *   Machine Learning (Basics)
# *   SQL
# *   Firebase
# *   Git
# *   GitHub
# *   VS Code
# *   OOPS
# *   Data Structures
# *   DBMS
# *   Operating Systems
# *   HTML
# *   CSS
# *   JavaScript
#
# **Experience summary**
# *   **AIML Intern — AICTE Internship Program:** Applied AI/ML concepts to real-world problems, built and evaluated basic ML models for classification and prediction using Python.
# *   **AI Intern - Learn Square Technologies:** Completed a six-week internship focused on AI concepts and applications, gained hands-on experience with Python for AI tasks including data handling and basic model building.
#
# **Education**
# *   **B.Tech in Information Technology**
#     *   Vishnu Institute of Technology, Bhimavaram
#     *   2023 – Present
#     *   CGPA: 9.51
#
# **Tools & Technologies**
# *   Java
# ...

# %%
def parse_job_description(jd_text):
    prompt = f"""
Extract:
- Required skills
- Responsibilities
- Preferred qualifications

Job Description:
{jd_text}

Return in bullet points.
"""
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=prompt
    )
    return response.text
sample_jd = """
We are looking for a aiml engineer.
Must have experience with python and  ml frameworks.
 with specialized fields such as generative AI,DL,NLP.With a foundational knowldege of statistics and mathematics.
"""
parsed_jd=print(parse_job_description(sample_jd))
# Out:
# Here's the extracted information:
#
# **Required skills:**
# *   Experience with Python
# *   Experience with ML frameworks
# *   Specialized fields: Generative AI, Deep Learning (DL), Natural Language Processing (NLP)
# *   Foundational knowledge of statistics
# *   Foundational knowledge of mathematics
#
# **Responsibilities:**
# *   (None explicitly mentioned)
#
# **Preferred qualifications:**
# *   (None explicitly mentioned as "preferred" – all listed items appear to be requirements)

# %%
parsed_resume=parse_resume(text)
parsed_jd=parse_job_description(sample_jd)

# %%
def ats_match(parsed_resume, parsed_jd):
    prompt = f"""
You are an Applicant Tracking System.

Compare the resume and job description.

Resume:
{parsed_resume}

Job Description:
{parsed_jd}

Provide:
1. Match percentage (0-100)
2. Matching skills
3. Missing skills
4. Strengths
5. Improvement suggestions
"""
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=prompt
    )
    return response.text
print(ats_match(parsed_resume, parsed_jd))
# Out:
# As an Applicant Tracking System, I have analyzed the provided resume against the job description.
#
# ---
#
# ### **1. Match Percentage**
# **43%**
#
# ### **2. Matching Skills**
# *   Python
# *   Generative AI
# *   Experience with ML frameworks (implied by building and evaluating basic ML models)
#
# ### **3. Missing Skills**
# *   Deep Learning (DL)
# *   Natural Language Processing (NLP)
# *   Foundational knowledge of Statistics
# *   Foundational knowledge of Mathematics
#
# ### **4. Strengths**
# *   **Strong Foundational AI/ML Knowledge:** Demonstrates direct experience with Generative AI, Agentic AI, and Prompt Engineering, including practical application with the Google Gemini API.
# *   **Solid Programming & Core CS Skills:** Proficient in Python, Java, C, SQL, OOPS, Data Structures, and DBMS, which are excellent foundational skills for an AI/ML role.
# ...
